# %%
import pandas

text_file = open('terms_sample_100.txt', 'r')

terms = text_file.readlines()
cleaned_terms = [x.rstrip() for x in terms]


#print (cleaned_terms)

# %% [markdown]
# Checking if word tokens from the list are present in wordnet:

# %%
from nltk.corpus import wordnet as wn
wn_lemmas = set(wn.all_lemma_names())
count_present = 0
count_missing = 0

for term in cleaned_terms:
    if term in wn_lemmas:
#        print (term, " is in WordNet")
        #syn_sets = [wn.synsets(cleaned_term) for cleaned_term in cleaned_terms]
        count_present+=1
    else:
#        print (term, " is not in WordNet")
        count_missing+=1

        
print ("In wordNet: ", count_present, "not in wordnet: ", count_missing )
# Out:
# In wordNet:  60 not in wordnet:  40

# %%
lower_present = 0
lower_missing = 0
lowercased_terms = [x.lower() for x in cleaned_terms]

for term in lowercased_terms:
    if term in wn_lemmas:
#        print (term, " is in WordNet")
        #syn_sets = [wn.synsets(cleaned_term) for cleaned_term in cleaned_terms]
        lower_present+=1
    else:
#        print (term, " is not in WordNet")
        lower_missing+=1
print ("In wordNet: ", lower_present, "not in wordnet: ", lower_missing )
# Out:
# In wordNet:  60 not in wordnet:  40

# %% [markdown]
# Many are missing, we need to lemmatize words in the list, mostly a copy-paste from [here](https://rustyonrampage.github.io/text-mining/2017/11/23/stemming-and-lemmatization-with-python-and-nltk.html)

# %%
from nltk.corpus import wordnet as wn
from nltk.stem.wordnet import WordNetLemmatizer
from collections import Counter 

wnl = WordNetLemmatizer()

lemmatized_terms = []

def get_pos( word ):
    w_synsets = wn.synsets(word)

    pos_counts = Counter()
    pos_counts["n"] = len(  [ item for item in w_synsets if item.pos()=="n"]  )
    pos_counts["v"] = len(  [ item for item in w_synsets if item.pos()=="v"]  )
    pos_counts["a"] = len(  [ item for item in w_synsets if item.pos()=="a"]  )
    pos_counts["r"] = len(  [ item for item in w_synsets if item.pos()=="r"]  )
    
    most_common_pos_list = pos_counts.most_common(3)
    return most_common_pos_list[0][0] # first indexer for getting the top POS from l

for word in lowercased_terms:
    word.lower()
    lemma = wnl.lemmatize( word, get_pos(word) )
    lemmatized_terms.append(lemma)

# %% [markdown]
# Now let us search in a lemmatized version of the list (with the help of [this](https://stackoverflow.com/questions/48805672/printing-synsets-of-words-in-a-list-in-python) ):

# %%
wn_lemmas = set(wn.all_lemma_names())
count_present = 0
count_missing = 0

def get_synsets(word_term):
    synsets = []
    definitions = []
    #hypernyms = []
    #hyponyms = []
    
    syns = wn.synsets(word_term)
    word = syns[0].lemmas()[0].name()
    definition = syns[0].definition()
    examples = syns[0].examples()
    synonyms = []
    antonyms = []
    
    hypo = lambda s: s.hyponyms()
    hyper = lambda s: s.hypernyms()
    
    
    for syn in wn.synsets(word_term):
        hyponyms = list(syn.closure(hypo))
        hypernyms = list(syn.closure(hyper))
        
        for l in syn.lemmas():     
            synonyms.append(l.name())
            if l.antonyms():
                antonyms.append(l.antonyms()[0].name())
    
    return definition, examples, set(synonyms), set(antonyms), hyponyms, hypernyms

for term in lemmatized_terms:
    if term in wn_lemmas:
        print ("============", term, "==========")
        #syn_sets = [wn.synsets(cleaned_term) for cleaned_term in cleaned_terms]
        count_present+=1        
        defs, examples, set_synonyms, set_antonyms, hyponyms, hypernyms = get_synsets(term)
        print ("Definition: ", defs)
        print ("Examples: ", examples )
        print ("Synonyms: ", set_synonyms )
        print ("Hyponyms: ", hyponyms)
        print ("Hypernyms: ", hypernyms)
        
    else:
        #print (term, " is not in WordNet")
        count_missing+=1


        
print ("Lemmatized version is in wordNet: ", count_present, "Lemmatized version is still not in wordnet: ", count_missing )
# Out:
# ============ sperm ==========
# Definition:  the male reproductive cell; the male gamete
# Examples:  ['a sperm is mostly a nucleus surrounded by little other cellular material']
# Synonyms:  {'spermatozoan', 'sperm', 'spermatozoon', 'sperm_cell'}
# Hyponyms:  []
# Hypernyms:  [Synset('gamete.n.01'), Synset('reproductive_cell.n.01'), Synset('cell.n.02'), Synset('living_thing.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ infertility ==========
# Definition:  the state of being unable to produce offspring; in a woman it is an inability to conceive; in a man it is an inability to impregnate
# Examples:  []
# Synonyms:  {'infertility', 'sterility'}
# Hyponyms:  [Synset('barrenness.n.01'), Synset('cacogenesis.n.01'), Synset('dysgenesis.n.01'), Synset('impotence.n.02'), Synset('erectile_dysfunction.n.01')]
# Hypernyms:  [Synset('physical_condition.n.01'), Synset('condition.n.01'), Synset('state.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ cell ==========
# Definition:  any small compartment
# Examples:  ['the cells of a honeycomb']
# Synonyms:  {'cell', 'electric_cell', 'jail_cell', 'cellular_telephone', 'cubicle', 'cadre', 'cellphone', 'cellular_phone', 'mobile_phone', 'prison_cell'}
# Hyponyms:  [Synset('bullpen.n.02'), Synset('cooler.n.03'), Synset('dungeon.n.02'), Synset('guardroom.n.01'), Synset('hold.n.07'), Synset('sweatbox.n.01'), Synset('oubliette.n.01')]
# Hypernyms:  [Synset('room.n.01'), Synset('area.n.05'), Synset('structure.n.01'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ patient ==========
# Definition:  a person who requires medical care
# Examples:  ['the number of emergency patients has grown rapidly']
# Synonyms:  {'patient', 'patient_role', 'affected_role'}
# Hyponyms:  []
# Hypernyms:  []
# ============ semen ==========
# Definition:  the thick white fluid containing spermatozoa that is ejaculated by the male genital tract
# Examples:  []
# Synonyms:  {'ejaculate', 'come', 'semen', 'seed', 'seminal_fluid', 'cum'}
# Hyponyms:  [Synset('milt.n.02')]
# Hypernyms:  [Synset('liquid_body_substance.n.01'), Synset('body_substance.n.01'), Synset('substance.n.01'), Synset('matter.n.03'), Synset('part.n.01'), Synset('physical_entity.n.01'), Synset('relation.n.01'), Synset('entity.n.01'), Synset('abstraction.n.06')]
# ============ dna ==========
# Definition:  (biochemistry) a long linear polymer found in the nucleus of a cell and formed from nucleotides and shaped like a double helix; associated with the transmission of genetic information
# Examples:  ['DNA is the king of molecules']
# Synonyms:  {'deoxyribonucleic_acid', 'desoxyribonucleic_acid', 'DNA'}
# Hyponyms:  [Synset('complementary_dna.n.01'), Synset('episome.n.01'), Synset('exon.n.01'), Synset('intron.n.01'), Synset('junk_dna.n.01'), Synset('operon.n.01'), Synset('recombinant_deoxyribonucleic_acid.n.01'), Synset('sticky_end.n.01'), Synset('transposon.n.01'), Synset('dscdna.n.01'), Synset('provirus.n.01')]
# Hypernyms:  [Synset('polymer.n.01'), Synset('compound.n.02'), Synset('chemical.n.01'), Synset('material.n.01'), Synset('substance.n.01'), Synset('matter.n.03'), Synset('part.n.01'), Synset('physical_entity.n.01'), Synset('relation.n.01'), Synset('entity.n.01'), Synset('abstraction.n.06')]
# ============ infertile ==========
# Definition:  incapable of reproducing
# Examples:  ['an infertile couple']
# Synonyms:  {'infertile', 'sterile', 'unfertile'}
# Hyponyms:  []
# Hypernyms:  []
# ============ fig ==========
# Definition:  a diagram or picture illustrating textual material
# Examples:  ['the area covered can be seen from Figure 2']
# Synonyms:  {'Libyan_Islamic_Group', 'Libyan_Islamic_Fighting_Group', "Al-Jama'a_al-Islamiyyah_al-Muqatilah_bi-Libya", 'Libyan_Fighting_Group', 'common_fig_tree', 'FIG', 'Ficus_carica', 'figure', 'fig', 'common_fig'}
# Hyponyms:  []
# Hypernyms:  [Synset('edible_fruit.n.01'), Synset('fruit.n.01'), Synset('produce.n.01'), Synset('reproductive_structure.n.01'), Synset('food.n.02'), Synset('plant_organ.n.01'), Synset('solid.n.01'), Synset('plant_part.n.01'), Synset('matter.n.03'), Synset('natural_object.n.01'), Synset('physical_entity.n.01'), Synset('whole.n.02'), Synset('entity.n.01'), Synset('object.n.01')]
# ============ gene ==========
# Definition:  (genetics) a segment of DNA that is involved in producing a polypeptide chain; it can include regions preceding and following the coding DNA as well as introns between the exons; it is considered a unit of heredity
# Examples:  ['genes were formerly called factors']
# Synonyms:  {'gene', 'cistron', 'factor'}
# Hyponyms:  [Synset('allele.n.01'), Synset('dominant_gene.n.01'), Synset('genetic_marker.n.01'), Synset('homeotic_gene.n.01'), Synset('lethal_gene.n.01'), Synset('linkage_group.n.01'), Synset('modifier.n.04'), Synset('mutant_gene.n.01'), Synset('nonallele.n.01'), Synset('oncogene.n.01'), Synset('operator_gene.n.01'), Synset('polygene.n.01'), Synset('proto-oncogene.n.01'), Synset('recessive_gene.n.01'), Synset('regulatory_gene.n.01'), Synset('repressor_gene.n.01'), Synset('structural_gene.n.01'), Synset('suppressor.n.02'), Synset('transgene.n.01'), Synset('x-linked_gene.n.01'), Synset('y-linked_gene.n.01'), Synset('dominant_allele.n.01'), Synset('recessive_allele.n.01'), Synset('homeobox.n.01'), Synset('cystic_fibrosis_transport_regulator.n.01'), Synset('tumor_suppressor_gene.n.01')]
# Hypernyms:  [Synset('sequence.n.01'), Synset('series.n.01'), Synset('ordering.n.01'), Synset('arrangement.n.02'), Synset('group.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ gene ==========
# Definition:  (genetics) a segment of DNA that is involved in producing a polypeptide chain; it can include regions preceding and following the coding DNA as well as introns between the exons; it is considered a unit of heredity
# Examples:  ['genes were formerly called factors']
# Synonyms:  {'gene', 'cistron', 'factor'}
# Hyponyms:  [Synset('allele.n.01'), Synset('dominant_gene.n.01'), Synset('genetic_marker.n.01'), Synset('homeotic_gene.n.01'), Synset('lethal_gene.n.01'), Synset('linkage_group.n.01'), Synset('modifier.n.04'), Synset('mutant_gene.n.01'), Synset('nonallele.n.01'), Synset('oncogene.n.01'), Synset('operator_gene.n.01'), Synset('polygene.n.01'), Synset('proto-oncogene.n.01'), Synset('recessive_gene.n.01'), Synset('regulatory_gene.n.01'), Synset('repressor_gene.n.01'), Synset('structural_gene.n.01'), Synset('suppressor.n.02'), Synset('transgene.n.01'), Synset('x-linked_gene.n.01'), Synset('y-linked_gene.n.01'), Synset('dominant_allele.n.01'), Synset('recessive_allele.n.01'), Synset('homeobox.n.01'), Synset('cystic_fibrosis_transport_regulator.n.01'), Synset('tumor_suppressor_gene.n.01')]
# Hypernyms:  [Synset('sequence.n.01'), Synset('series.n.01'), Synset('ordering.n.01'), Synset('arrangement.n.02'), Synset('group.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ protein ==========
# Definition:  any of a large group of nitrogenous organic compounds that are essential constituents of living cells; consist of polymers of amino acids; essential in the diet of animals for growth and for repair of tissues; can be obtained from meat and eggs and milk and legumes
# Examples:  ['a diet high in protein']
# Synonyms:  {'protein'}
# Hyponyms:  [Synset('actomyosin.n.01'), Synset('aleurone.n.01'), Synset('amyloid.n.02'), Synset('antibody.n.01'), Synset('apoenzyme.n.01'), Synset('capsid.n.02'), Synset('conjugated_protein.n.01'), Synset('cytokine.n.01'), Synset('enzyme.n.01'), Synset('ferritin.n.01'), Synset('fibrin.n.01'), Synset('filaggrin.n.01'), Synset('gluten.n.01'), Synset('growth_factor.n.01'), Synset('haptoglobin.n.01'), Synset('iodoprotein.n.01'), Synset('nucleoprotein.n.01'), Synset('opsin.n.01'), Synset('phosphoprotein.n.01'), Synset('plasma_protein.n.01'), Synset('prostate_specific_antigen.n.01'), Synset('proteome.n.01'), Synset('recombinant_protein.n.01'), Synset('simple_protein.n.01'), Synset('abo_antibodies.n.01'), Synset('agglutinin.n.01'), Synset('antitoxin.n.01'), Synset('autoantibody.n.01'), Synset('heterophil_antibody.n.01'), Synset('immunoglobulin.n.01'), Synset('isoantibody.n.01'), Synset('monoclonal_antibody.n.01'), Synset('opsonin.n.01'), Synset('precipitin.n.01'), Synset('rh_antibody.n.01'), Synset('glycoprotein.n.01'), Synset('hemoprotein.n.01'), Synset('lipoprotein.n.01'), Synset('lymphokine.n.01'), Synset('tumor_necrosis_factor.n.01'), Synset('adenosine_deaminase.n.01'), Synset('amylase.n.01'), Synset('catalase.n.01'), Synset('cholinesterase.n.01'), Synset('coagulase.n.01'), Synset('collagenase.n.01'), Synset('complement.n.05'), Synset('cyclooxygenase.n.01'), Synset('de-iodinase.n.01'), Synset('decarboxylase.n.01'), Synset('disaccharidase.n.01'), Synset('elastase.n.01'), Synset('enterokinase.n.01'), Synset('histaminase.n.01'), Synset('hyaluronidase.n.01'), Synset('isomerase.n.01'), Synset('kinase.n.01'), Synset('lipase.n.01'), Synset('lysozyme.n.01'), Synset('monoamine_oxidase.n.01'), Synset('nitrogenase.n.01'), Synset('nuclease.n.01'), Synset('oxidase.n.01'), Synset('oxidoreductase.n.01'), Synset('papain.n.01'), Synset('penicillinase.n.01'), Synset('pepsin.n.01'), Synset('pepsinogen.n.01'), Synset('phosphatase.n.01'), Synset('plasmin.n.01'), Synset('polymerase.n.01'), Synset('protease.n.01'), Synset('reductase.n.01'), Synset('rennin.n.01'), Synset('secretase.n.01'), Synset('streptodornase.n.01'), Synset('streptokinase.n.01'), Synset('superoxide_dismutase.n.01'), Synset('telomerase.n.01'), Synset('transferase.n.01'), Synset('trypsin.n.01'), Synset('urease.n.01'), Synset('zymase.n.01'), Synset('corn_gluten.n.01'), Synset('wheat_gluten.n.01'), Synset('nerve_growth_factor.n.01'), Synset('thyroglobulin.n.01'), Synset('thyroprotein.n.01'), Synset('casein.n.01'), Synset('coagulation_factor.n.01'), Synset('gamma_globulin.n.01'), Synset('actin.n.01'), Synset('albumin.n.01'), Synset('globin.n.01'), Synset('globulin.n.01'), Synset('glutelin.n.01'), Synset('histone.n.01'), Synset('prolamine.n.01'), Synset('protamine.n.01'), Synset('scleroprotein.n.01'), Synset('isoagglutinin.n.01'), Synset('antivenin.n.01'), Synset('tetanus_antitoxin.n.01'), Synset('rheumatoid_factor.n.01'), Synset('immunoglobulin_a.n.01'), Synset('immunoglobulin_d.n.01'), Synset('immunoglobulin_e.n.01'), Synset('immunoglobulin_g.n.01'), Synset('immunoglobulin_m.n.01'), Synset('tetanus_immunoglobulin.n.01'), Synset('infliximab.n.01'), Synset('cluster_of_differentiation_4.n.01'), Synset('cluster_of_differentiation_8.n.01'), Synset('erythropoietin.n.01'), Synset('lectin.n.01'), Synset('mucin.n.01'), Synset('mucoid.n.01'), Synset('cytochrome.n.01'), Synset('hemoglobin.n.01'), Synset('myoglobin.n.01'), Synset('high-density_lipoprotein.n.01'), Synset('low-density_lipoprotein.n.01'), Synset('very_low_density_lipoprotein.n.01'), Synset('interleukin.n.01'), Synset('ptyalin.n.01'), Synset('thrombin.n.01'), Synset('cyclooxygenase-1.n.01'), Synset('cyclooxygenase-2.n.01'), Synset('invertase.n.01'), Synset('lactase.n.01'), Synset('endonuclease.n.01'), Synset('exonuclease.n.01'), Synset('peroxidase.n.01'), Synset('oxygenase.n.01'), Synset('plasminogen.n.01'), Synset('dna_polymerase.n.01'), Synset('reverse_transcriptase.n.01'), Synset('transcriptase.n.01'), Synset('angiotensin_converting_e ...
# Hypernyms:  [Synset('macromolecule.n.01'), Synset('molecule.n.01'), Synset('organic_compound.n.01'), Synset('unit.n.05'), Synset('compound.n.02'), Synset('thing.n.12'), Synset('chemical.n.01'), Synset('physical_entity.n.01'), Synset('material.n.01'), Synset('entity.n.01'), Synset('substance.n.01'), Synset('matter.n.03'), Synset('part.n.01'), Synset('relation.n.01'), Synset('abstraction.n.06')]
# ============ cell ==========
# Definition:  any small compartment
# Examples:  ['the cells of a honeycomb']
# Synonyms:  {'cell', 'electric_cell', 'jail_cell', 'cellular_telephone', 'cubicle', 'cadre', 'cellphone', 'cellular_phone', 'mobile_phone', 'prison_cell'}
# Hyponyms:  [Synset('bullpen.n.02'), Synset('cooler.n.03'), Synset('dungeon.n.02'), Synset('guardroom.n.01'), Synset('hold.n.07'), Synset('sweatbox.n.01'), Synset('oubliette.n.01')]
# Hypernyms:  [Synset('room.n.01'), Synset('area.n.05'), Synset('structure.n.01'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ spermatozoon ==========
# Definition:  the male reproductive cell; the male gamete
# Examples:  ['a sperm is mostly a nucleus surrounded by little other cellular material']
# Synonyms:  {'spermatozoan', 'sperm', 'spermatozoon', 'sperm_cell'}
# Hyponyms:  []
# Hypernyms:  [Synset('gamete.n.01'), Synset('reproductive_cell.n.01'), Synset('cell.n.02'), Synset('living_thing.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ ml ==========
# Definition:  a metric unit of volume equal to one thousandth of a liter
# Examples:  []
# Synonyms:  {'cubic_centimeter', 'mil', 'cc', 'milliliter', 'ml', 'millilitre', 'cubic_centimetre'}
# Hyponyms:  []
# Hypernyms:  [Synset('metric_capacity_unit.n.01'), Synset('metric_unit.n.01'), Synset('volume_unit.n.01'), Synset('unit_of_measurement.n.01'), Synset('definite_quantity.n.01'), Synset('measure.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ pregnancy ==========
# Definition:  the state of being pregnant; the period from conception to birth when a woman carries a developing fetus in her uterus
# Examples:  []
# Synonyms:  {'gestation', 'pregnancy', 'maternity'}
# Hyponyms:  [Synset('ectopic_pregnancy.n.01'), Synset('entopic_pregnancy.n.01'), Synset('gravida.n.01'), Synset('gravidity.n.01'), Synset('parity.n.01'), Synset('placenta_previa.n.01'), Synset('trouble.n.06'), Synset('abdominal_pregnancy.n.01'), Synset('ovarian_pregnancy.n.01'), Synset('tubal_pregnancy.n.01')]
# Hypernyms:  [Synset('physical_condition.n.01'), Synset('condition.n.01'), Synset('state.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ pone ==========
# Definition:  cornbread often made without milk or eggs and baked or fried (southern)
# Examples:  []
# Synonyms:  {'cornpone', 'pone'}
# Hyponyms:  []
# Hypernyms:  [Synset('cornbread.n.01'), Synset('quick_bread.n.01'), Synset('bread.n.01'), Synset('baked_goods.n.01'), Synset('starches.n.01'), Synset('food.n.02'), Synset('foodstuff.n.02'), Synset('solid.n.01'), Synset('food.n.01'), Synset('matter.n.03'), Synset('substance.n.07'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ testis ==========
# Definition:  one of the two male reproductive glands that produce spermatozoa and secrete androgens
# Examples:  ['she kicked him in the balls and got away']
# Synonyms:  {'testis', 'testicle', 'ballock', 'nut', 'bollock', 'orchis', 'ball', 'egg'}
# Hyponyms:  [Synset('cobblers.n.02'), Synset('undescended_testis.n.01')]
# Hypernyms:  [Synset('gonad.n.01'), Synset('male_reproductive_gland.n.01'), Synset('endocrine_gland.n.01'), Synset('reproductive_organ.n.01'), Synset('gland.n.01'), Synset('organ.n.01'), Synset('body_part.n.01'), Synset('part.n.03'), Synset('thing.n.12'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ testis ==========
# Definition:  one of the two male reproductive glands that produce spermatozoa and secrete androgens
# Examples:  ['she kicked him in the balls and got away']
# Synonyms:  {'testis', 'testicle', 'ballock', 'nut', 'bollock', 'orchis', 'ball', 'egg'}
# Hyponyms:  [Synset('cobblers.n.02'), Synset('undescended_testis.n.01')]
# Hypernyms:  [Synset('gonad.n.01'), Synset('male_reproductive_gland.n.01'), Synset('endocrine_gland.n.01'), Synset('reproductive_organ.n.01'), Synset('gland.n.01'), Synset('organ.n.01'), Synset('body_part.n.01'), Synset('part.n.03'), Synset('thing.n.12'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ clinical ==========
# Definition:  relating to a clinic or conducted in or as if in a clinic and depending on direct observation of patients
# Examples:  ['clinical observation', 'clinical case study']
# Synonyms:  {'clinical'}
# Hyponyms:  []
# Hypernyms:  []
# ============ fertility ==========
# Definition:  the ratio of live births in an area to the population of that area; expressed per 1000 population per year
# Examples:  []
# Synonyms:  {'rankness', 'richness', 'birthrate', 'fecundity', 'fertility', 'fertility_rate', 'birth_rate', 'prolificacy', 'natality'}
# Hyponyms:  []
# Hypernyms:  [Synset('fruitfulness.n.01'), Synset('quality.n.01'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ deletion ==========
# Definition:  any process whereby sounds or words are left out of spoken words or phrases
# Examples:  []
# Synonyms:  {'cut', 'deletion', 'excision', 'omission'}
# Hyponyms:  [Synset('censoring.n.02'), Synset('expunction.n.01'), Synset('expurgation.n.01'), Synset('bowdlerism.n.01'), Synset('comstockery.n.01'), Synset('bowdlerization.n.02')]
# Hypernyms:  [Synset('removal.n.01'), Synset('separation.n.09'), Synset('change_of_integrity.n.01'), Synset('change.n.03'), Synset('action.n.01'), Synset('act.n.02'), Synset('event.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ fertile ==========
# Definition:  capable of reproducing
# Examples:  []
# Synonyms:  {'prolific', 'rich', 'fertile', 'fecund', 'fat', 'productive'}
# Hyponyms:  []
# Hypernyms:  []
# ============ testicular ==========
# Definition:  of or involving the testes
# Examples:  ['testicular cancer']
# Synonyms:  {'testicular'}
# Hyponyms:  []
# Hypernyms:  []
# ============ spermatogenesis ==========
# Definition:  development of spermatozoa
# Examples:  []
# Synonyms:  {'spermatogenesis'}
# Hyponyms:  []
# Hypernyms:  [Synset('gametogenesis.n.01'), Synset('growth.n.01'), Synset('organic_process.n.01'), Synset('process.n.06'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ cftr ==========
# Definition:  the gene that is mutated in cystic fibrosis
# Examples:  []
# Synonyms:  {'cystic_fibrosis_transport_regulator', 'CFTR'}
# Hyponyms:  []
# Hypernyms:  [Synset('mutant_gene.n.01'), Synset('gene.n.01'), Synset('sequence.n.01'), Synset('series.n.01'), Synset('ordering.n.01'), Synset('arrangement.n.02'), Synset('group.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ genetic ==========
# Definition:  occurring among members of a family usually by heredity
# Examples:  ['an inherited disease', 'familial traits', 'genetically transmitted features']
# Synonyms:  {'genic', 'inherited', 'familial', 'transmitted', 'genetic', 'transmissible', 'genetical', 'hereditary'}
# Hyponyms:  []
# Hypernyms:  []
# ============ ci ==========
# Definition:  a unit of radioactivity equal to the amount of a radioactive isotope that decays at the rate of 37,000,000,000 disintegrations per second
# Examples:  []
# Synonyms:  {'ci', 'curie', 'Ci', '101', 'one_hundred_one', 'hundred_and_one'}
# Hyponyms:  []
# Hypernyms:  []
# ============ motility ==========
# Definition:  ability to move spontaneously and independently
# Examples:  []
# Synonyms:  {'motion', 'movement', 'motility', 'move'}
# Hyponyms:  [Synset('abduction.n.02'), Synset('adduction.n.01'), Synset('agitation.n.05'), Synset('body_english.n.01'), Synset('circumduction.n.01'), Synset('disturbance.n.05'), Synset('eurythmy.n.01'), Synset('eye_movement.n.01'), Synset('fetal_movement.n.01'), Synset('flit.n.01'), Synset('gesture.n.01'), Synset('headshake.n.01'), Synset('inclination.n.08'), Synset('inversion.n.08'), Synset('inversion.n.09'), Synset('jerk.n.02'), Synset('kick.n.06'), Synset('kneel.n.01'), Synset('lurch.n.03'), Synset('opening.n.05'), Synset('prostration.n.03'), Synset('reach.n.03'), Synset('reciprocation.n.02'), Synset('reclining.n.01'), Synset('retraction.n.02'), Synset('retroflection.n.03'), Synset('rotation.n.01'), Synset('shutting.n.01'), Synset('sitting.n.01'), Synset('sitting.n.02'), Synset('snap.n.12'), Synset('squat.n.03'), Synset('standing.n.03'), Synset('straddle.n.03'), Synset('stroke.n.12'), Synset('sweep.n.06'), Synset('toss.n.03'), Synset('vibration.n.01'), Synset('wave.n.02'), Synset('waver.n.03'), Synset('wiggle.n.01'), Synset('shaking.n.01'), Synset('stirring.n.01'), Synset('wag.n.02'), Synset('worrying.n.02'), Synset('agitation.n.04'), Synset('circus.n.03'), Synset('commotion.n.02'), Synset('disorganization.n.02'), Synset('disruption.n.04'), Synset('furor.n.02'), Synset('havoc.n.01'), Synset('melee.n.01'), Synset('outburst.n.03'), Synset('rampage.n.01'), Synset('upset.n.02'), Synset('nystagmus.n.01'), Synset('saccade.n.01'), Synset('jab.n.01'), Synset('mudra.n.01'), Synset('bob.n.07'), Synset('nod.n.02'), Synset('stoop.n.01'), Synset('upset.n.05'), Synset('swimming_kick.n.01'), Synset('rock.n.07'), Synset('outreach.n.01'), Synset('circumvolution.n.01'), Synset('feather.n.02'), Synset('gyration.n.02'), Synset('pivot.n.03'), Synset('pronation.n.01'), Synset('spin.n.02'), Synset('spiral.n.06'), Synset('supination.n.01'), Synset('turnout.n.07'), Synset('twist.n.13'), Synset('wind.n.08'), Synset('beat.n.09'), Synset('blow.n.01'), Synset('bow.n.09'), Synset('keystroke.n.01'), Synset('tremor.n.01'), Synset('joggle.n.02'), Synset('bustle.n.01'), Synset('dislocation.n.02'), Synset('surprise.n.03'), Synset('brouhaha.n.02'), Synset('wilding.n.02'), Synset('physiological_nystagmus.n.01'), Synset('post-rotational_nystagmus.n.01'), Synset('rotational_nystagmus.n.01'), Synset('nutation.n.01'), Synset('dolphin_kick.n.01'), Synset('flutter_kick.n.01'), Synset('frog_kick.n.01'), Synset('scissors_kick.n.01'), Synset('thrash.n.01'), Synset('birling.n.01'), Synset('pirouette.n.01'), Synset('twiddle.n.01'), Synset('backhander.n.01'), Synset('box.n.10'), Synset('clip.n.06'), Synset('counterblow.n.01'), Synset('hammer.n.08'), Synset('kick.n.01'), Synset('knock.n.05'), Synset('knockdown.n.01'), Synset('knockout.n.02'), Synset('punch.n.01'), Synset('shot.n.14'), Synset('smack.n.06'), Synset('smacker.n.02'), Synset('stab.n.02'), Synset('stinger.n.05'), Synset('swat.n.01'), Synset('swing.n.03'), Synset('thump.n.02'), Synset('thwack.n.01'), Synset('uppercut.n.01'), Synset('wallop.n.02'), Synset('whip.n.05'), Synset('down-bow.n.01'), Synset('up-bow.n.01'), Synset('dropkick.n.01'), Synset('goal-kick.n.01'), Synset('goal-kick.n.02'), Synset('place_kick.n.01'), Synset('punt.n.03'), Synset('technical_knockout.n.01'), Synset('counterpunch.n.01'), Synset('haymaker.n.02'), Synset('hook.n.07'), Synset('jab.n.02'), Synset('rabbit_punch.n.01'), Synset('sucker_punch.n.01'), Synset('cheap_shot.n.02'), Synset('spank.n.01'), Synset('lunge.n.02'), Synset('remise.n.03'), Synset('free_kick.n.01'), Synset('kickoff.n.01'), Synset('roundhouse.n.02'), Synset('corner_kick.n.01')]
# Hypernyms:  [Synset('change.n.03'), Synset('action.n.01'), Synset('act.n.02'), Synset('event.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ germ ==========
# Definition:  anything that provides inspiration for later work
# Examples:  []
# Synonyms:  {'seed', 'microbe', 'bug', 'source', 'germ'}
# Hyponyms:  []
# Hypernyms:  [Synset('microorganism.n.01'), Synset('organism.n.01'), Synset('living_thing.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ reproductive ==========
# Definition:  producing new life or offspring
# Examples:  ['the reproductive potential of a species is its relative capacity to reproduce itself under optimal conditions', 'the reproductive or generative organs']
# Synonyms:  {'generative', 'procreative', 'reproductive'}
# Hyponyms:  []
# Hypernyms:  []
# ============ allele ==========
# Definition:  (genetics) either of a pair (or series) of alternative forms of a gene that can occupy the same locus on a particular chromosome and that control the same character
# Examples:  ['some alleles are dominant over others']
# Synonyms:  {'allelomorph', 'allele'}
# Hyponyms:  [Synset('dominant_allele.n.01'), Synset('recessive_allele.n.01')]
# Hypernyms:  [Synset('gene.n.01'), Synset('sequence.n.01'), Synset('series.n.01'), Synset('ordering.n.01'), Synset('arrangement.n.02'), Synset('group.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ chromosome ==========
# Definition:  a threadlike strand of DNA in the cell nucleus that carries the genes in a linear order
# Examples:  ['humans have 22 chromosome pairs plus two sex chromosomes']
# Synonyms:  {'chromosome'}
# Hyponyms:  [Synset('acentric_chromosome.n.01'), Synset('acrocentric_chromosome.n.01'), Synset('autosome.n.01'), Synset('metacentric_chromosome.n.01'), Synset('sex_chromosome.n.01'), Synset('telocentric_chromosome.n.01'), Synset('x_chromosome.n.01'), Synset('xx.n.02'), Synset('xxx.n.02'), Synset('xxy.n.01'), Synset('xy.n.01'), Synset('xyy.n.01'), Synset('y_chromosome.n.01')]
# Hypernyms:  [Synset('body.n.04'), Synset('natural_object.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ al ==========
# Definition:  a silvery ductile metallic element found primarily in bauxite
# Examples:  []
# Synonyms:  {'AL', 'aluminium', 'Heart_of_Dixie', 'aluminum', 'Camellia_State', 'Al', 'Alabama', 'atomic_number_13'}
# Hyponyms:  []
# Hypernyms:  [Synset('south.n.01')]
# ============ embryo ==========
# Definition:  (botany) a minute rudimentary plant contained within a seed or an archegonium
# Examples:  []
# Synonyms:  {'conceptus', 'embryo', 'fertilized_egg'}
# Hyponyms:  [Synset('blastula.n.01'), Synset('gastrula.n.01'), Synset('morula.n.01'), Synset('blastocyst.n.01')]
# Hypernyms:  [Synset('animal.n.01'), Synset('organism.n.01'), Synset('living_thing.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ deletion ==========
# Definition:  any process whereby sounds or words are left out of spoken words or phrases
# Examples:  []
# Synonyms:  {'cut', 'deletion', 'excision', 'omission'}
# Hyponyms:  [Synset('censoring.n.02'), Synset('expunction.n.01'), Synset('expurgation.n.01'), Synset('bowdlerism.n.01'), Synset('comstockery.n.01'), Synset('bowdlerization.n.02')]
# Hypernyms:  [Synset('removal.n.01'), Synset('separation.n.09'), Synset('change_of_integrity.n.01'), Synset('change.n.03'), Synset('action.n.01'), Synset('act.n.02'), Synset('event.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ genotype ==========
# Definition:  a group of organisms sharing a specific genetic constitution
# Examples:  []
# Synonyms:  {'genotype', 'genetic_constitution'}
# Hyponyms:  []
# Hypernyms:  [Synset('constitution.n.04'), Synset('property.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ v ==========
# Definition:  a unit of potential equal to the potential difference between two points on a conductor carrying a current of 1 ampere when the power dissipated between the two points is 1 watt; equivalent to the potential difference across a resistance of 1 ohm when 1 ampere of current flows through it
# Examples:  []
# Synonyms:  {'Little_Phoebe', 'fivesome', 'fin', 'five', 'quintet', '5', 'quint', 'volt', 'cinque', 'V', 'quintuplet', 'Phoebe', 'atomic_number_23', 'vanadium', 'pentad', 'v'}
# Hyponyms:  []
# Hypernyms:  []
# ============ mm ==========
# Definition:  a metric unit of length equal to one thousandth of a meter
# Examples:  []
# Synonyms:  {'mm', 'millimetre', 'millimeter'}
# Hyponyms:  []
# Hypernyms:  [Synset('metric_linear_unit.n.01'), Synset('linear_unit.n.01'), Synset('metric_unit.n.01'), Synset('unit_of_measurement.n.01'), Synset('definite_quantity.n.01'), Synset('measure.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ protein ==========
# Definition:  any of a large group of nitrogenous organic compounds that are essential constituents of living cells; consist of polymers of amino acids; essential in the diet of animals for growth and for repair of tissues; can be obtained from meat and eggs and milk and legumes
# Examples:  ['a diet high in protein']
# Synonyms:  {'protein'}
# Hyponyms:  [Synset('actomyosin.n.01'), Synset('aleurone.n.01'), Synset('amyloid.n.02'), Synset('antibody.n.01'), Synset('apoenzyme.n.01'), Synset('capsid.n.02'), Synset('conjugated_protein.n.01'), Synset('cytokine.n.01'), Synset('enzyme.n.01'), Synset('ferritin.n.01'), Synset('fibrin.n.01'), Synset('filaggrin.n.01'), Synset('gluten.n.01'), Synset('growth_factor.n.01'), Synset('haptoglobin.n.01'), Synset('iodoprotein.n.01'), Synset('nucleoprotein.n.01'), Synset('opsin.n.01'), Synset('phosphoprotein.n.01'), Synset('plasma_protein.n.01'), Synset('prostate_specific_antigen.n.01'), Synset('proteome.n.01'), Synset('recombinant_protein.n.01'), Synset('simple_protein.n.01'), Synset('abo_antibodies.n.01'), Synset('agglutinin.n.01'), Synset('antitoxin.n.01'), Synset('autoantibody.n.01'), Synset('heterophil_antibody.n.01'), Synset('immunoglobulin.n.01'), Synset('isoantibody.n.01'), Synset('monoclonal_antibody.n.01'), Synset('opsonin.n.01'), Synset('precipitin.n.01'), Synset('rh_antibody.n.01'), Synset('glycoprotein.n.01'), Synset('hemoprotein.n.01'), Synset('lipoprotein.n.01'), Synset('lymphokine.n.01'), Synset('tumor_necrosis_factor.n.01'), Synset('adenosine_deaminase.n.01'), Synset('amylase.n.01'), Synset('catalase.n.01'), Synset('cholinesterase.n.01'), Synset('coagulase.n.01'), Synset('collagenase.n.01'), Synset('complement.n.05'), Synset('cyclooxygenase.n.01'), Synset('de-iodinase.n.01'), Synset('decarboxylase.n.01'), Synset('disaccharidase.n.01'), Synset('elastase.n.01'), Synset('enterokinase.n.01'), Synset('histaminase.n.01'), Synset('hyaluronidase.n.01'), Synset('isomerase.n.01'), Synset('kinase.n.01'), Synset('lipase.n.01'), Synset('lysozyme.n.01'), Synset('monoamine_oxidase.n.01'), Synset('nitrogenase.n.01'), Synset('nuclease.n.01'), Synset('oxidase.n.01'), Synset('oxidoreductase.n.01'), Synset('papain.n.01'), Synset('penicillinase.n.01'), Synset('pepsin.n.01'), Synset('pepsinogen.n.01'), Synset('phosphatase.n.01'), Synset('plasmin.n.01'), Synset('polymerase.n.01'), Synset('protease.n.01'), Synset('reductase.n.01'), Synset('rennin.n.01'), Synset('secretase.n.01'), Synset('streptodornase.n.01'), Synset('streptokinase.n.01'), Synset('superoxide_dismutase.n.01'), Synset('telomerase.n.01'), Synset('transferase.n.01'), Synset('trypsin.n.01'), Synset('urease.n.01'), Synset('zymase.n.01'), Synset('corn_gluten.n.01'), Synset('wheat_gluten.n.01'), Synset('nerve_growth_factor.n.01'), Synset('thyroglobulin.n.01'), Synset('thyroprotein.n.01'), Synset('casein.n.01'), Synset('coagulation_factor.n.01'), Synset('gamma_globulin.n.01'), Synset('actin.n.01'), Synset('albumin.n.01'), Synset('globin.n.01'), Synset('globulin.n.01'), Synset('glutelin.n.01'), Synset('histone.n.01'), Synset('prolamine.n.01'), Synset('protamine.n.01'), Synset('scleroprotein.n.01'), Synset('isoagglutinin.n.01'), Synset('antivenin.n.01'), Synset('tetanus_antitoxin.n.01'), Synset('rheumatoid_factor.n.01'), Synset('immunoglobulin_a.n.01'), Synset('immunoglobulin_d.n.01'), Synset('immunoglobulin_e.n.01'), Synset('immunoglobulin_g.n.01'), Synset('immunoglobulin_m.n.01'), Synset('tetanus_immunoglobulin.n.01'), Synset('infliximab.n.01'), Synset('cluster_of_differentiation_4.n.01'), Synset('cluster_of_differentiation_8.n.01'), Synset('erythropoietin.n.01'), Synset('lectin.n.01'), Synset('mucin.n.01'), Synset('mucoid.n.01'), Synset('cytochrome.n.01'), Synset('hemoglobin.n.01'), Synset('myoglobin.n.01'), Synset('high-density_lipoprotein.n.01'), Synset('low-density_lipoprotein.n.01'), Synset('very_low_density_lipoprotein.n.01'), Synset('interleukin.n.01'), Synset('ptyalin.n.01'), Synset('thrombin.n.01'), Synset('cyclooxygenase-1.n.01'), Synset('cyclooxygenase-2.n.01'), Synset('invertase.n.01'), Synset('lactase.n.01'), Synset('endonuclease.n.01'), Synset('exonuclease.n.01'), Synset('peroxidase.n.01'), Synset('oxygenase.n.01'), Synset('plasminogen.n.01'), Synset('dna_polymerase.n.01'), Synset('reverse_transcriptase.n.01'), Synset('transcriptase.n.01'), Synset('angiotensin_converting_e ...
# Hypernyms:  [Synset('macromolecule.n.01'), Synset('molecule.n.01'), Synset('organic_compound.n.01'), Synset('unit.n.05'), Synset('compound.n.02'), Synset('thing.n.12'), Synset('chemical.n.01'), Synset('physical_entity.n.01'), Synset('material.n.01'), Synset('entity.n.01'), Synset('substance.n.01'), Synset('matter.n.03'), Synset('part.n.01'), Synset('relation.n.01'), Synset('abstraction.n.06')]
# ============ mutant ==========
# Definition:  (biology) an organism that has characteristics resulting from chromosomal alteration
# Examples:  []
# Synonyms:  {'variation', 'mutant', 'sport', 'mutation'}
# Hyponyms:  []
# Hypernyms:  []
# ============ usa ==========
# Definition:  North American republic containing 50 states - 48 conterminous states in North America plus Alaska in northwest North America and the Hawaiian Islands in the Pacific Ocean; achieved independence in 1776
# Examples:  []
# Synonyms:  {'United_States', 'America', 'U.S.A.', 'US_Army', 'the_States', 'Army', 'U._S._Army', 'United_States_of_America', 'US', 'USA', 'U.S.', 'United_States_Army'}
# Hyponyms:  []
# Hypernyms:  [Synset('agency.n.01'), Synset('administrative_unit.n.01'), Synset('unit.n.03'), Synset('organization.n.01'), Synset('social_group.n.01'), Synset('group.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ min ==========
# Definition:  a unit of time equal to 60 seconds or 1/60th of an hour
# Examples:  ['he ran a 4 minute mile']
# Synonyms:  {'Fukien', 'Min', 'Fukkianese', 'min', 'Amoy', 'minute', 'Hokkianese', 'Min_dialect', 'Taiwanese'}
# Hyponyms:  []
# Hypernyms:  []
# ============ x ==========
# Definition:  the cardinal number that is the sum of nine and one; the base of the decimal system
# Examples:  []
# Synonyms:  {'cristal', 'X', 'x', 'go', 'ex', 'disco_biscuit', 'decade', 'XTC', 'Adam', 'ecstasy', 'tenner', '10', 'hug_drug', 'ten'}
# Hyponyms:  []
# Hypernyms:  []
# ============ oocyte ==========
# Definition:  a female gametocyte that develops into an ovum after two meiotic divisions
# Examples:  []
# Synonyms:  {'oocyte'}
# Hyponyms:  []
# Hypernyms:  [Synset('gametocyte.n.01'), Synset('cell.n.02'), Synset('living_thing.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ cohort ==========
# Definition:  a company of companions or supporters
# Examples:  []
# Synonyms:  {'age_bracket', 'cohort', 'age_group'}
# Hyponyms:  [Synset('aged.n.01'), Synset('young.n.09')]
# Hypernyms:  [Synset('people.n.01'), Synset('group.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ fsh ==========
# Definition:  a gonadotropic hormone that is secreted by the anterior pituitary and stimulates growth of Graafian follicles in female mammals, and activates the cells in male mammals that form sperm
# Examples:  []
# Synonyms:  {'FSH', 'follicle-stimulating_hormone'}
# Hyponyms:  []
# Hypernyms:  [Synset('gonadotropin.n.01'), Synset('hormone.n.01'), Synset('secretion.n.02'), Synset('liquid_body_substance.n.01'), Synset('body_substance.n.01'), Synset('substance.n.01'), Synset('matter.n.03'), Synset('part.n.01'), Synset('physical_entity.n.01'), Synset('relation.n.01'), Synset('entity.n.01'), Synset('abstraction.n.06')]
# ============ antibody ==========
# Definition:  any of a large variety of proteins normally present in the body or produced in response to an antigen which it neutralizes, thus producing an immune response
# Examples:  []
# Synonyms:  {'antibody'}
# Hyponyms:  [Synset('abo_antibodies.n.01'), Synset('agglutinin.n.01'), Synset('antitoxin.n.01'), Synset('autoantibody.n.01'), Synset('heterophil_antibody.n.01'), Synset('immunoglobulin.n.01'), Synset('isoantibody.n.01'), Synset('monoclonal_antibody.n.01'), Synset('opsonin.n.01'), Synset('precipitin.n.01'), Synset('rh_antibody.n.01'), Synset('isoagglutinin.n.01'), Synset('antivenin.n.01'), Synset('tetanus_antitoxin.n.01'), Synset('rheumatoid_factor.n.01'), Synset('immunoglobulin_a.n.01'), Synset('immunoglobulin_d.n.01'), Synset('immunoglobulin_e.n.01'), Synset('immunoglobulin_g.n.01'), Synset('immunoglobulin_m.n.01'), Synset('tetanus_immunoglobulin.n.01'), Synset('infliximab.n.01'), Synset('reagin.n.01')]
# Hypernyms:  [Synset('protein.n.01'), Synset('macromolecule.n.01'), Synset('molecule.n.01'), Synset('organic_compound.n.01'), Synset('unit.n.05'), Synset('compound.n.02'), Synset('thing.n.12'), Synset('chemical.n.01'), Synset('physical_entity.n.01'), Synset('material.n.01'), Synset('entity.n.01'), Synset('substance.n.01'), Synset('matter.n.03'), Synset('part.n.01'), Synset('relation.n.01'), Synset('abstraction.n.06')]
# ============ ii ==========
# Definition:  the cardinal number that is the sum of one and one or a numeral representing this number
# Examples:  []
# Synonyms:  {'two', 'deuce', 'ii', 'II', '2'}
# Hyponyms:  []
# Hypernyms:  []
# ============ ca ==========
# Definition:  a white metallic element that burns with a brilliant light; the fifth most abundant element in the earth's crust; an important component of most plants and animals
# Examples:  []
# Synonyms:  {'CA', 'Ca', 'California', 'calcium', 'Golden_State', 'atomic_number_20', 'Calif.'}
# Hyponyms:  []
# Hypernyms:  []
# ============ embryo ==========
# Definition:  (botany) a minute rudimentary plant contained within a seed or an archegonium
# Examples:  []
# Synonyms:  {'conceptus', 'embryo', 'fertilized_egg'}
# Hyponyms:  [Synset('blastula.n.01'), Synset('gastrula.n.01'), Synset('morula.n.01'), Synset('blastocyst.n.01')]
# Hypernyms:  [Synset('animal.n.01'), Synset('organism.n.01'), Synset('living_thing.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ mutation ==========
# Definition:  (biology) an organism that has characteristics resulting from chromosomal alteration
# Examples:  []
# Synonyms:  {'mutation', 'variation', 'mutant', 'genetic_mutation', 'sport', 'chromosomal_mutation'}
# Hyponyms:  []
# Hypernyms:  [Synset('change.n.01'), Synset('happening.n.01'), Synset('event.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ mutation ==========
# Definition:  (biology) an organism that has characteristics resulting from chromosomal alteration
# Examples:  []
# Synonyms:  {'mutation', 'variation', 'mutant', 'genetic_mutation', 'sport', 'chromosomal_mutation'}
# Hyponyms:  []
# Hypernyms:  [Synset('change.n.01'), Synset('happening.n.01'), Synset('event.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ ph ==========
# Definition:  (from potential of Hydrogen) the logarithm of the reciprocal of hydrogen-ion concentration in gram atoms per liter; provides a measure on a scale from 0 to 14 of the acidity or alkalinity of a solution (where 7 is neutral and greater than 7 is more basic and less than 7 is more acidic);
# Examples:  []
# Synonyms:  {'pH_scale', 'pH'}
# Hyponyms:  [Synset('acidity.n.03'), Synset('alkalinity.n.01'), Synset('neutrality.n.03'), Synset('hyperacidity.n.01')]
# Hypernyms:  [Synset('hydrogen_ion_concentration.n.01'), Synset('concentration.n.01'), Synset('property.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ prevalence ==========
# Definition:  the quality of prevailing generally; being widespread
# Examples:  ['he was surprised by the prevalence of optimism about the future']
# Synonyms:  {'prevalence', 'preponderance'}
# Hyponyms:  []
# Hypernyms:  [Synset('number.n.01'), Synset('amount.n.02'), Synset('magnitude.n.01'), Synset('property.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ serum ==========
# Definition:  an amber, watery fluid, rich in proteins, that separates out when blood coagulates
# Examples:  []
# Synonyms:  {'blood_serum', 'serum'}
# Hyponyms:  [Synset('antiserum.n.01'), Synset('whey.n.01')]
# Hypernyms:  [Synset('liquid_body_substance.n.01'), Synset('body_substance.n.01'), Synset('substance.n.01'), Synset('matter.n.03'), Synset('part.n.01'), Synset('physical_entity.n.01'), Synset('relation.n.01'), Synset('entity.n.01'), Synset('abstraction.n.06')]
# ============ polymorphism ==========
# Definition:  (genetics) the genetic variation within a population that natural selection can operate on
# Examples:  []
# Synonyms:  {'pleomorphism', 'polymorphism'}
# Hyponyms:  [Synset('dimorphism.n.02')]
# Hypernyms:  [Synset('organic_phenomenon.n.01'), Synset('natural_phenomenon.n.01'), Synset('phenomenon.n.01'), Synset('process.n.06'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ assay ==========
# Definition:  an appraisal of the state of affairs
# Examples:  ['they made an assay of the contents', 'a check on its dependability under stress']
# Synonyms:  {'seek', 'assay', 'attempt', 'check', 'essay', 'try'}
# Hyponyms:  [Synset('endeavor.v.01'), Synset('fight.v.03'), Synset('gamble.v.01'), Synset('give_it_a_whirl.v.01'), Synset('grope.v.02'), Synset('have_a_go.v.01'), Synset('risk.v.01'), Synset('take_a_dare.v.02'), Synset('buck.v.01'), Synset('struggle.v.02'), Synset('take_pains.v.01'), Synset('flounder.v.02'), Synset('tug.v.02'), Synset('go_for_broke.v.01'), Synset('luck_it.v.01'), Synset('bell_the_cat.v.01'), Synset('venture.v.03'), Synset('strive.v.02'), Synset('extend_oneself.v.01'), Synset('kill_oneself.v.01'), Synset('trouble_oneself.v.01')]
# Hypernyms:  [Synset('act.v.01')]
# ============ epididymis ==========
# Definition:  a convoluted tubule in each testis; carries sperm to vas deferens
# Examples:  []
# Synonyms:  {'epididymis'}
# Hyponyms:  []
# Hypernyms:  [Synset('duct.n.01'), Synset('passage.n.07'), Synset('structure.n.04'), Synset('body_part.n.01'), Synset('part.n.03'), Synset('thing.n.12'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ primer ==========
# Definition:  an introductory textbook
# Examples:  []
# Synonyms:  {'flat_coat', 'fuzee', 'fuze', 'primer_coat', 'ground', 'undercoat', 'primer', 'priming_coat', 'priming', 'fuse', 'fusee'}
# Hyponyms:  [Synset('couch.n.02')]
# Hypernyms:  [Synset('coat_of_paint.n.01'), Synset('coating.n.01'), Synset('paint.n.01'), Synset('covering.n.02'), Synset('coloring_material.n.01'), Synset('artifact.n.01'), Synset('material.n.01'), Synset('whole.n.02'), Synset('substance.n.01'), Synset('object.n.01'), Synset('matter.n.03'), Synset('part.n.01'), Synset('physical_entity.n.01'), Synset('relation.n.01'), Synset('entity.n.01'), Synset('abstraction.n.06')]
# ============ seminal ==========
# Definition:  pertaining to or containing or consisting of semen
# Examples:  ['seminal fluid']
# Synonyms:  {'originative', 'seminal', 'germinal'}
# Hyponyms:  []
# Hypernyms:  []
# ============ spermatid ==========
# Definition:  an immature gamete produced by a spermatocyte; develops into a spermatozoon
# Examples:  []
# Synonyms:  {'spermatid'}
# Hyponyms:  []
# Hypernyms:  [Synset('gamete.n.01'), Synset('reproductive_cell.n.01'), Synset('cell.n.02'), Synset('living_thing.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ snp ==========
# Definition:  (genetics) genetic variation in a DNA sequence that occurs when a single nucleotide in a genome is altered; SNPs are usually considered to be point mutations that have been evolutionarily successful enough to recur in a significant proportion of the population of a species
# Examples:  []
# Synonyms:  {'single_nucleotide_polymorphism', 'SNP'}
# Hyponyms:  []
# Hypernyms:  [Synset('polymorphism.n.01'), Synset('organic_phenomenon.n.01'), Synset('natural_phenomenon.n.01'), Synset('phenomenon.n.01'), Synset('process.n.06'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ morphology ==========
# Definition:  the branch of biology that deals with the structure of animals and plants
# Examples:  []
# Synonyms:  {'syllable_structure', 'morphology', 'sound_structure', 'word_structure', 'geomorphology'}
# Hyponyms:  [Synset('petrology.n.01'), Synset('tectonics.n.02')]
# Hypernyms:  [Synset('geophysics.n.01'), Synset('geology.n.01'), Synset('earth_science.n.01'), Synset('natural_science.n.01'), Synset('science.n.01'), Synset('discipline.n.01'), Synset('knowledge_domain.n.01'), Synset('content.n.05'), Synset('cognition.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ acid ==========
# Definition:  any of various water-soluble compounds having a sour taste and capable of turning litmus red and reacting with a base to form a salt
# Examples:  []
# Synonyms:  {'Elvis', 'superman', 'pane', 'sulfurous', 'caustic', 'back_breaker', 'acid', 'Lucy_in_the_sky_with_diamonds', 'window_pane', 'sulphurous', 'bitter', 'acidulous', 'dose', 'acidulent', 'acerbic', 'blistering', 'acrid', 'loony_toons', 'virulent', 'battery-acid', 'acerb', 'Zen', 'vitriolic', 'dot', 'acidic'}
# Hyponyms:  []
# Hypernyms:  []
# ============ rna ==========
# Definition:  (biochemistry) a long linear polymer of nucleotides found in the nucleus but mainly in the cytoplasm of a cell where it is associated with microsomes; it transmits genetic information from DNA to the cytoplasm and controls certain chemical processes in the cell
# Examples:  ['ribonucleic acid is the genetic material of some viruses']
# Synonyms:  {'ribonucleic_acid', 'RNA'}
# Hyponyms:  [Synset('messenger_rna.n.01'), Synset('nuclear_rna.n.01'), Synset('transfer_rna.n.01')]
# Hypernyms:  [Synset('polymer.n.01'), Synset('compound.n.02'), Synset('chemical.n.01'), Synset('material.n.01'), Synset('substance.n.01'), Synset('matter.n.03'), Synset('part.n.01'), Synset('physical_entity.n.01'), Synset('relation.n.01'), Synset('entity.n.01'), Synset('abstraction.n.06')]
# ============ transcript ==========
# Definition:  something that has been transcribed; a written record (usually typewritten) of dictated or recorded speech
# Examples:  ['he read a transcript of the interrogation', 'you can obtain a transcript of this radio program by sending a self-addressed envelope to the station']
# Synonyms:  {'transcript', 'copy'}
# Hyponyms:  []
# Hypernyms:  [Synset('written_record.n.01'), Synset('record.n.01'), Synset('evidence.n.02'), Synset('indication.n.01'), Synset('communication.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ phenotype ==========
# Definition:  what an organism looks like as a consequence of the interaction of its genotype and the environment
# Examples:  []
# Synonyms:  {'phenotype'}
# Hyponyms:  []
# Hypernyms:  [Synset('constitution.n.04'), Synset('property.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# ============ fluid ==========
# Definition:  a substance that is fluid at room temperature and pressure
# Examples:  []
# Synonyms:  {'mobile', 'runny', 'unstable', 'fluid', 'liquid', 'smooth', 'fluent'}
# Hyponyms:  []
# Hypernyms:  []
# ============ sd ==========
# Definition:  a state in north central United States
# Examples:  []
# Synonyms:  {'Coyote_State', 'South_Dakota', 'SD', 'Mount_Rushmore_State'}
# Hyponyms:  []
# Hypernyms:  []
# ============ reference ==========
# Definition:  a remark that calls attention to something or someone
# Examples:  ['she made frequent mention of her promotion', 'there was no mention of it', 'the speaker made several references to his wife']
# Synonyms:  {'character', 'cite', 'reference', 'mention', 'acknowledgment', 'point_of_reference', 'book_of_facts', 'reference_point', 'consultation', 'address', 'quotation', 'reference_work', 'credit', 'character_reference', 'source', 'reference_book', 'denotation', 'computer_address', 'extension', 'citation'}
# Hyponyms:  []
# Hypernyms:  [Synset('write.v.01'), Synset('create_verbally.v.01'), Synset('make.v.03')]
# ============ score ==========
# Definition:  a number or letter indicating quality (especially of a student's performance)
# Examples:  ['she made good marks in algebra', 'grade A milk', 'what was your score on your homework?']
# Synonyms:  {'sexual_conquest', 'scotch', 'grudge', 'tally', 'make', 'account', 'grievance', 'nock', 'seduce', 'score', 'hit', 'rack_up', 'mark', 'grade', 'musical_score'}
# Hyponyms:  []
# Hypernyms:  [Synset('measure.v.04'), Synset('evaluate.v.02'), Synset('think.v.03')]
# ============ nd ==========
# Definition:  a yellow trivalent metallic element of the rare earth group; occurs in monazite and bastnasite in association with cerium and lanthanum and praseodymium
# Examples:  []
# Synonyms:  {'North_Dakota', 'ND', 'Peace_Garden_State', 'atomic_number_60', 'neodymium', 'Nd'}
# Hyponyms:  []
# Hypernyms:  []
# ============ tt ==========
# Definition:  (astronomy) a measure of time defined by Earth's orbital motion; terrestrial time is mean solar time corrected for the irregularities of the Earth's motions
# Examples:  []
# Synonyms:  {'TT', 'ephemeris_time', 'Republic_of_Palau', 'Micronesia', 'terrestrial_time', 'TDT', 'Palau', 'terrestrial_dynamical_time', 'Federated_States_of_Micronesia'}
# Hyponyms:  []
# Hypernyms:  []
# ============ snp ==========
# Definition:  (genetics) genetic variation in a DNA sequence that occurs when a single nucleotide in a genome is altered; SNPs are usually considered to be point mutations that have been evolutionarily successful enough to recur in a significant proportion of the population of a species
# Examples:  []
# Synonyms:  {'single_nucleotide_polymorphism', 'SNP'}
# Hyponyms:  []
# Hypernyms:  [Synset('polymorphism.n.01'), Synset('organic_phenomenon.n.01'), Synset('natural_phenomenon.n.01'), Synset('phenomenon.n.01'), Synset('process.n.06'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
# ============ correlation ==========
# Definition:  a reciprocal relation between two or more things
# Examples:  []
# Synonyms:  {'correlativity', 'correlation_coefficient', 'correlational_statistics', 'correlation', 'coefficient_of_correlation'}
# Hyponyms:  [Synset('curvilinear_correlation.n.01'), Synset('negative_correlation.n.01'), Synset('partial_correlation.n.01'), Synset('positive_correlation.n.01'), Synset('spurious_correlation.n.01'), Synset('first-order_correlation.n.01')]
# Hypernyms:  [Synset('statistics.n.01'), Synset('applied_mathematics.n.01'), Synset('mathematics.n.01'), Synset('science.n.01'), Synset('discipline.n.01'), Synset('knowledge_domain.n.01'), Synset('content.n.05'), Synset('cognition.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
# Lemmatized version is in wordNet:  75 Lemmatized version is still not in wordnet:  25

# %% [markdown]
# As for hyponyms and hypernyms, we have to include Synset objects, not just words, see discussion here:
# https://stackoverflow.com/questions/45388056/how-to-remove-synset-and-pos-tag-numbers-on-hypernyms-and-hyponyms
# Manual selection of the domain hyponyms/hypernym is thus needed.
